# %%
import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import pickle

# %%
df = pd.read_csv('C:\\DataSets\\StockAnalysis\\dhaval\\2017-18.csv', usecols = range(0,8))
df.columns = ['Symbol', 'date', 'hr:min', 'open', 'high', 'low', 'close', 'Volume']

# %%
df.head(5)
df.tail(5)
# Out:
#        Symbol      date hr:min     open     high      low    close  Volume
# 0  HEROMOTOCO  20170301  09:08  3156.90  3156.90  3156.90  3156.90     370
# 1  HEROMOTOCO  20170301  09:16  3160.20  3198.00  3150.00  3157.75   26845
# 2  HEROMOTOCO  20170301  09:17  3158.45  3182.75  3158.45  3180.55   18156
# 3  HEROMOTOCO  20170301  09:18  3180.00  3185.00  3175.05  3185.00   11324
# 4  HEROMOTOCO  20170301  09:19  3184.05  3193.95  3181.85  3182.40   12501
#              Symbol      date hr:min   open   high     low  close  Volume
# 20177823  AMBUJACEM  20181231  15:30  224.9  225.0  224.85  225.0    5039
# 20177824  AMBUJACEM  20181231  15:32  225.1  225.1  225.10  225.1       0
# 20177825  AMBUJACEM  20181231  15:41  225.1  225.1  225.10  225.1     242
# 20177826  AMBUJACEM  20181231  15:52  225.1  225.1  225.10  225.1       1
# 20177827  AMBUJACEM  20181231  16:36  225.1  225.1  225.10  225.1       0

# %%
df_hero = df[df['Symbol'] == 'HEROMOTOCO']

# %%
df_hero.head(5)
df_hero.tail(5)
# Out:
#        Symbol      date hr:min     open     high      low    close  Volume
# 0  HEROMOTOCO  20170301  09:08  3156.90  3156.90  3156.90  3156.90     370
# 1  HEROMOTOCO  20170301  09:16  3160.20  3198.00  3150.00  3157.75   26845
# 2  HEROMOTOCO  20170301  09:17  3158.45  3182.75  3158.45  3180.55   18156
# 3  HEROMOTOCO  20170301  09:18  3180.00  3185.00  3175.05  3185.00   11324
# 4  HEROMOTOCO  20170301  09:19  3184.05  3193.95  3181.85  3182.40   12501
#              Symbol      date hr:min     open     high      low    close  \
# 9783241  HEROMOTOCO  20181231  15:52  3104.25  3104.25  3104.25  3104.25
# 9783242  HEROMOTOCO  20181231  15:56  3104.25  3104.25  3104.25  3104.25
# 9783243  HEROMOTOCO  20181231  15:58  3104.25  3104.25  3104.25  3104.25
# 9783244  HEROMOTOCO  20181231  16:00  3104.25  3104.25  3104.25  3104.25
# 9783245  HEROMOTOCO  20181231  16:36  3104.25  3104.25  3104.25  3104.25
#
#          Volume
# 9783241      10
# 9783242       4
# 9783243       1
# ...

# %%
df_hero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187882 entries, 0 to 9783245
# Data columns (total 8 columns):
# Symbol    187882 non-null object
# date      187882 non-null int64
# hr:min    187882 non-null object
# open      187882 non-null float64
# high      187882 non-null float64
# low       187882 non-null float64
# close     187882 non-null float64
# Volume    187882 non-null int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 12.9+ MB

# %%
df_hero.date = df_hero.date.astype(str)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df_hero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187882 entries, 0 to 9783245
# Data columns (total 8 columns):
# Symbol    187882 non-null object
# date      187882 non-null object
# hr:min    187882 non-null object
# open      187882 non-null float64
# high      187882 non-null float64
# low       187882 non-null float64
# close     187882 non-null float64
# Volume    187882 non-null int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 12.9+ MB

# %%
df_hero['date'] =  pd.to_datetime(df_hero['date'])
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_hero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187882 entries, 0 to 9783245
# Data columns (total 8 columns):
# Symbol    187882 non-null object
# date      187882 non-null datetime64[ns]
# hr:min    187882 non-null object
# open      187882 non-null float64
# high      187882 non-null float64
# low       187882 non-null float64
# close     187882 non-null float64
# Volume    187882 non-null int64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(2)
# memory usage: 12.9+ MB

# %%
df_hero['year'] = pd.DatetimeIndex(df_hero['date']).year
df_hero['month'] = pd.DatetimeIndex(df_hero['date']).month
df_hero['day'] = pd.DatetimeIndex(df_hero['date']).day
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_hero.head()
# Out:
#        Symbol       date hr:min     open     high      low    close  Volume  \
# 0  HEROMOTOCO 2017-03-01  09:08  3156.90  3156.90  3156.90  3156.90     370
# 1  HEROMOTOCO 2017-03-01  09:16  3160.20  3198.00  3150.00  3157.75   26845
# 2  HEROMOTOCO 2017-03-01  09:17  3158.45  3182.75  3158.45  3180.55   18156
# 3  HEROMOTOCO 2017-03-01  09:18  3180.00  3185.00  3175.05  3185.00   11324
# 4  HEROMOTOCO 2017-03-01  09:19  3184.05  3193.95  3181.85  3182.40   12501
#
#    year  month  day
# 0  2017      3    1
# 1  2017      3    1
# 2  2017      3    1
# 3  2017      3    1
# 4  2017      3    1

# %%
df = df.rename(columns = {'hr:mm': 'hrmm'})

# %%
df_hero[['hour','minute']] = df_hero['hr:min'].str.split(":",expand=True,)

# %%
df_hero.head()
# Out:
#        Symbol       date hr:min     open     high      low    close  Volume  \
# 0  HEROMOTOCO 2017-03-01  09:08  3156.90  3156.90  3156.90  3156.90     370
# 1  HEROMOTOCO 2017-03-01  09:16  3160.20  3198.00  3150.00  3157.75   26845
# 2  HEROMOTOCO 2017-03-01  09:17  3158.45  3182.75  3158.45  3180.55   18156
# 3  HEROMOTOCO 2017-03-01  09:18  3180.00  3185.00  3175.05  3185.00   11324
# 4  HEROMOTOCO 2017-03-01  09:19  3184.05  3193.95  3181.85  3182.40   12501
#
#    year  month  day hour minute
# 0  2017      3    1   09     08
# 1  2017      3    1   09     16
# 2  2017      3    1   09     17
# 3  2017      3    1   09     18
# 4  2017      3    1   09     19

# %%
import sqlite3

# %%
conn = sqlite3.connect('C:\\DataSets\\StockAnalysis\\dhaval\\StockAnalysis.db')
print ("Opened database successfully")
# Out:
# Opened database successfully

# %%
df_hero.to_sql('df_hero',conn, if_exists = 'replace')
#rfmdm = pd.read_sql("select * from RFMDM",conn)
print ("new table got created successfully")
conn.close()
# Out:
# new table got created successfully

# %% [markdown]
# #ran the following queries to delete the unncessary records
# SELECT * FROM df_hero where hour = '15' and minute > '30'
#
# SELECT * FROM df_hero where hour = '09' and minute == '08'
#
# SELECT * FROM df_hero where hour = '16'
#
# delete from df_hero where hour = '15' and minute > '30'
#
# delete from df_hero where hour = '09' and minute == '08'
#
# delete from df_hero where hour = '16'

# %%
conn = sqlite3.connect('C:\\DataSets\\StockAnalysis\\dhaval\\StockAnalysis.db')
print ("Opened database successfully")
# Out:
# Opened database successfully

# %%
df_hero = pd.read_sql_query("select * from df_hero", conn)
#rfmdm = pd.read_sql("select * from RFMDM",conn)

# %%
conn.close()

# %%
df_hero.head(10)
# Out:
#    index      Symbol                 date hr:min     open     high      low  \
# 0      1  HEROMOTOCO  2017-03-01 00:00:00  09:16  3160.20  3198.00  3150.00
# 1      2  HEROMOTOCO  2017-03-01 00:00:00  09:17  3158.45  3182.75  3158.45
# 2      3  HEROMOTOCO  2017-03-01 00:00:00  09:18  3180.00  3185.00  3175.05
# 3      4  HEROMOTOCO  2017-03-01 00:00:00  09:19  3184.05  3193.95  3181.85
# 4      5  HEROMOTOCO  2017-03-01 00:00:00  09:20  3182.20  3182.20  3179.00
# 5      6  HEROMOTOCO  2017-03-01 00:00:00  09:21  3180.00  3181.00  3176.80
# 6      7  HEROMOTOCO  2017-03-01 00:00:00  09:22  3176.80  3177.00  3173.10
# 7      8  HEROMOTOCO  2017-03-01 00:00:00  09:23  3174.00  3184.90  3172.65
# 8      9  HEROMOTOCO  2017-03-01 00:00:00  09:24  3184.10  3185.00  3179.95
# 9     10  HEROMOTOCO  2017-03-01 00:00:00  09:25  3183.00  3185.00  3180.80
#
#      close  Volume  year  month  day hour minute
# 0  3157.75   26845  2017      3    1   09     16
# ...

# %%
df_hero.tail(50)
# Out:
#           index      Symbol                 date hr:min     open     high  \
# 184252  9783185  HEROMOTOCO  2018-12-31 00:00:00  14:41  3119.80  3120.00
# 184253  9783186  HEROMOTOCO  2018-12-31 00:00:00  14:42  3119.80  3120.55
# 184254  9783187  HEROMOTOCO  2018-12-31 00:00:00  14:43  3118.15  3119.75
# 184255  9783188  HEROMOTOCO  2018-12-31 00:00:00  14:44  3119.70  3119.75
# 184256  9783189  HEROMOTOCO  2018-12-31 00:00:00  14:45  3119.15  3119.95
# 184257  9783190  HEROMOTOCO  2018-12-31 00:00:00  14:46  3119.95  3121.50
# 184258  9783191  HEROMOTOCO  2018-12-31 00:00:00  14:47  3120.45  3120.45
# 184259  9783192  HEROMOTOCO  2018-12-31 00:00:00  14:48  3120.70  3120.95
# 184260  9783193  HEROMOTOCO  2018-12-31 00:00:00  14:49  3120.95  3120.95
# 184261  9783194  HEROMOTOCO  2018-12-31 00:00:00  14:50  3120.60  3120.90
# 184262  9783195  HEROMOTOCO  2018-12-31 00:00:00  14:51  3118.50  3120.45
# 184263  9783196  HEROMOTOCO  2018-12-31 00:00:00  14:52  3120.00  3120.00
# ...

# %% [raw]
# range = pd.date_range('2017-03-01', '2018-12-31', freq='15min')
# df_heroNew = pd.DataFrame(index = range)

# %%
df_hero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184302 entries, 0 to 184301
# Data columns (total 14 columns):
# index     184302 non-null int64
# Symbol    184302 non-null object
# date      184302 non-null object
# hr:min    184302 non-null object
# open      184302 non-null float64
# high      184302 non-null float64
# low       184302 non-null float64
# close     184302 non-null float64
# Volume    184302 non-null int64
# year      184302 non-null int64
# month     184302 non-null int64
# day       184302 non-null int64
# hour      184302 non-null object
# minute    184302 non-null object
# dtypes: float64(4), int64(5), object(5)
# memory usage: 19.7+ MB

# %%
df_hero['date1'] = pd.to_datetime(df_hero[['year', 'month', 'day', 'hour', 'minute']])

# %%
df_hero.head()
# Out:
#    index      Symbol                 date hr:min     open     high      low  \
# 0      1  HEROMOTOCO  2017-03-01 00:00:00  09:16  3160.20  3198.00  3150.00
# 1      2  HEROMOTOCO  2017-03-01 00:00:00  09:17  3158.45  3182.75  3158.45
# 2      3  HEROMOTOCO  2017-03-01 00:00:00  09:18  3180.00  3185.00  3175.05
# 3      4  HEROMOTOCO  2017-03-01 00:00:00  09:19  3184.05  3193.95  3181.85
# 4      5  HEROMOTOCO  2017-03-01 00:00:00  09:20  3182.20  3182.20  3179.00
#
#      close  Volume  year  month  day hour minute               date1
# 0  3157.75   26845  2017      3    1   09     16 2017-03-01 09:16:00
# 1  3180.55   18156  2017      3    1   09     17 2017-03-01 09:17:00
# 2  3185.00   11324  2017      3    1   09     18 2017-03-01 09:18:00
# 3  3182.40   12501  2017      3    1   09     19 2017-03-01 09:19:00
# 4  3180.00    4256  2017      3    1   09     20 2017-03-01 09:20:00

# %%
df_hero.index = df_hero['date1']
del df_hero['date1']

# %%
df_hero.head()
# Out:
#                      index      Symbol                 date hr:min     open  \
# date1
# 2017-03-01 09:16:00      1  HEROMOTOCO  2017-03-01 00:00:00  09:16  3160.20
# 2017-03-01 09:17:00      2  HEROMOTOCO  2017-03-01 00:00:00  09:17  3158.45
# 2017-03-01 09:18:00      3  HEROMOTOCO  2017-03-01 00:00:00  09:18  3180.00
# 2017-03-01 09:19:00      4  HEROMOTOCO  2017-03-01 00:00:00  09:19  3184.05
# 2017-03-01 09:20:00      5  HEROMOTOCO  2017-03-01 00:00:00  09:20  3182.20
#
#                         high      low    close  Volume  year  month  day hour  \
# date1
# 2017-03-01 09:16:00  3198.00  3150.00  3157.75   26845  2017      3    1   09
# 2017-03-01 09:17:00  3182.75  3158.45  3180.55   18156  2017      3    1   09
# 2017-03-01 09:18:00  3185.00  3175.05  3185.00   11324  2017      3    1   09
# 2017-03-01 09:19:00  3193.95  3181.85  3182.40   12501  2017      3    1   09
# 2017-03-01 09:20:00  3182.20  3179.00  3180.00    4256  2017      3    1   09
#
# ...

# %%
del df_hero['date']
del df_hero['year']
del df_hero['month']
del df_hero['day']
del df_hero['hour']
del df_hero['minute']
del df_hero['Symbol']
del df_hero['hr:min']
del df_hero['index']

# %%
df_hero.head()
df_hero.tail()
# Out:
#                         open     high      low    close  Volume
# date1
# 2017-03-01 09:16:00  3160.20  3198.00  3150.00  3157.75   26845
# 2017-03-01 09:17:00  3158.45  3182.75  3158.45  3180.55   18156
# 2017-03-01 09:18:00  3180.00  3185.00  3175.05  3185.00   11324
# 2017-03-01 09:19:00  3184.05  3193.95  3181.85  3182.40   12501
# 2017-03-01 09:20:00  3182.20  3182.20  3179.00  3180.00    4256
#                         open     high      low    close  Volume
# date1
# 2018-12-31 15:26:00  3095.00  3096.35  3093.50  3096.10    1062
# 2018-12-31 15:27:00  3096.10  3098.50  3092.75  3093.00    2843
# 2018-12-31 15:28:00  3092.95  3093.90  3089.20  3089.25    4627
# 2018-12-31 15:29:00  3089.25  3090.00  3087.00  3089.00    1435
# 2018-12-31 15:30:00  3089.00  3090.00  3088.15  3090.00    1552

# %%
daily_resampled_open = df_hero.open.resample('D').mean()

# %%
daily_resampled_open.head()
daily_resampled_open.tail()
# Out:
# date1
# 2017-01-02    3017.222667
# 2017-01-03    2996.833200
# 2017-01-04    2997.891600
# 2017-01-05    3049.512933
# 2017-01-06    3085.206000
# Freq: D, Name: open, dtype: float64
# date1
# 2018-12-27    3168.786533
# 2018-12-28    3133.935467
# 2018-12-29            NaN
# 2018-12-30            NaN
# 2018-12-31    3126.406133
# Freq: D, Name: open, dtype: float64

# %%
daily_resampled_high = df_hero.high.resample('D').mean()

# %%
daily_resampled_high.head()
daily_resampled_high.tail()
# Out:
# date1
# 2017-01-02    3018.472933
# 2017-01-03    2997.914933
# 2017-01-04    2998.888533
# 2017-01-05    3050.850533
# 2017-01-06    3086.294933
# Freq: D, Name: high, dtype: float64
# date1
# 2018-12-27    3170.097867
# 2018-12-28    3135.029733
# 2018-12-29            NaN
# 2018-12-30            NaN
# 2018-12-31    3127.561333
# Freq: D, Name: high, dtype: float64

# %%
daily_resampled_low = df_hero.low.resample('D').mean()

# %%
daily_resampled_low.head()
daily_resampled_low.tail()
# Out:
# date1
# 2017-01-02    3015.657333
# 2017-01-03    2995.574400
# 2017-01-04    2996.607600
# 2017-01-05    3048.052800
# 2017-01-06    3083.712667
# Freq: D, Name: low, dtype: float64
# date1
# 2018-12-27    3166.949600
# 2018-12-28    3132.719467
# 2018-12-29            NaN
# 2018-12-30            NaN
# 2018-12-31    3125.137333
# Freq: D, Name: low, dtype: float64

# %%
daily_resampled_close = df_hero.close.resample('D').mean()

# %%
daily_resampled_close.head()
daily_resampled_close.tail()
# Out:
# date1
# 2017-01-02    3017.014133
# 2017-01-03    2996.954667
# 2017-01-04    2997.808533
# 2017-01-05    3049.488667
# 2017-01-06    3085.004667
# Freq: D, Name: close, dtype: float64
# date1
# 2018-12-27    3168.510000
# 2018-12-28    3133.917200
# 2018-12-29            NaN
# 2018-12-30            NaN
# 2018-12-31    3126.203867
# Freq: D, Name: close, dtype: float64

# %%
daily_resampled_volume = df_hero.Volume.resample('D').mean()

# %%
daily_resampled_volume.head()
daily_resampled_volume.tail(100)
# Out:
# date1
# 2017-01-02     568.805333
# 2017-01-03    1208.008000
# 2017-01-04    1057.309333
# 2017-01-05    1022.453333
# 2017-01-06     709.893333
# Freq: D, Name: Volume, dtype: float64
# date1
# 2018-09-23            NaN
# 2018-09-24    1644.786096
# 2018-09-25    1234.824000
# 2018-09-26     952.632000
# 2018-09-27    2479.000000
# 2018-09-28    2218.029333
# 2018-09-29            NaN
# 2018-09-30            NaN
# 2018-10-01    1766.970667
# 2018-10-02            NaN
# 2018-10-03    1335.512000
# 2018-10-04    3125.661333
# 2018-10-05    2162.053333
# 2018-10-06            NaN
# 2018-10-07            NaN
# 2018-10-08    2029.170667
# 2018-10-09    1863.538667
# 2018-10-10    3105.690667
# 2018-10-11    1692.669333
# 2018-10-12    1023.789333
# 2018-10-13            NaN
# 2018-10-14            NaN
# 2018-10-15     559.181818
# 2018-10-16    1614.840000
# 2018-10-17    4329.394667
# 2018-10-18            NaN
# 2018-10-19    2081.754667
# 2018-10-20            NaN
# ...

# %%
daily_resampled_open_interpolated = daily_resampled_open.interpolate(method='linear')
daily_resampled_high_interpolated = daily_resampled_high.interpolate(method='linear')
daily_resampled_low_interpolated = daily_resampled_low.interpolate(method='linear')
daily_resampled_close_interpolated = daily_resampled_close.interpolate(method='linear')
daily_resampled_volume_interpolated = daily_resampled_volume.interpolate(method='linear')

# %%
daily_resampled_volume_interpolated.head(5)
# Out:
# date1
# 2017-01-02     568.805333
# 2017-01-03    1208.008000
# 2017-01-04    1057.309333
# 2017-01-05    1022.453333
# 2017-01-06     709.893333
# Freq: D, Name: Volume, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
daily_resampled_open_interpolated.plot()
plt.show()

# %%
plt.figure(figsize=(20,10))
daily_resampled_high_interpolated.plot()
plt.show();

# %%
plt.figure(figsize=(20,10))
daily_resampled_low_interpolated.plot()
plt.show()

# %%
plt.figure(figsize=(20,10))
daily_resampled_close_interpolated.plot()
plt.show()

# %%
plt.figure(figsize=(20,10))
daily_resampled_volume_interpolated.plot()
plt.show()

# %%
#merge the dataframes
df1 = pd.concat([daily_resampled_open, daily_resampled_high], axis = 1)

# %%
df1.head()
# Out:
#                    open         high
# date1
# 2017-01-02  3017.222667  3018.472933
# 2017-01-03  2996.833200  2997.914933
# 2017-01-04  2997.891600  2998.888533
# 2017-01-05  3049.512933  3050.850533
# 2017-01-06  3085.206000  3086.294933

# %%
#merge the dataframes
df2 = pd.concat([df1, daily_resampled_low], axis = 1)

# %%
df2.head()
# Out:
#                    open         high          low
# date1
# 2017-01-02  3017.222667  3018.472933  3015.657333
# 2017-01-03  2996.833200  2997.914933  2995.574400
# 2017-01-04  2997.891600  2998.888533  2996.607600
# 2017-01-05  3049.512933  3050.850533  3048.052800
# 2017-01-06  3085.206000  3086.294933  3083.712667

# %%
#merge the dataframes
df3 = pd.concat([df2, daily_resampled_close], axis = 1)

# %%
df3.head()
# Out:
#                    open         high          low        close
# date1
# 2017-01-02  3017.222667  3018.472933  3015.657333  3017.014133
# 2017-01-03  2996.833200  2997.914933  2995.574400  2996.954667
# 2017-01-04  2997.891600  2998.888533  2996.607600  2997.808533
# 2017-01-05  3049.512933  3050.850533  3048.052800  3049.488667
# 2017-01-06  3085.206000  3086.294933  3083.712667  3085.004667

# %%
#merge the dataframes
df4 = pd.concat([df3, daily_resampled_volume], axis = 1)

# %%
df4.head()
# Out:
#                    open         high          low        close       Volume
# date1
# 2017-01-02  3017.222667  3018.472933  3015.657333  3017.014133   568.805333
# 2017-01-03  2996.833200  2997.914933  2995.574400  2996.954667  1208.008000
# 2017-01-04  2997.891600  2998.888533  2996.607600  2997.808533  1057.309333
# 2017-01-05  3049.512933  3050.850533  3048.052800  3049.488667  1022.453333
# 2017-01-06  3085.206000  3086.294933  3083.712667  3085.004667   709.893333
